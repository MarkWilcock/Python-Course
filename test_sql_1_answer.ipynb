# %% [markdown]
# Note: 21st Sep 2025
# Do not use wuth Colab.  Both approaches - using pyodbc and sqlalchemy-pytds require a lot of configuration, too much for a course

# %%
# !pip install pandas sqlalchemy sqlalchemy-pytds

# %%
import pandas as pd
from sqlalchemy import create_engine

# Connection details
server = "zomalex-sql.database.windows.net"
database = "LearnSQL"
username = "student10"
password = "solveSQL!"

# Note the explicit :1433 port and connect_args for TLS
connection_string = (
    f"mssql+pytds://{username}:{password}@{server}:1433/{database}?encrypt=true&validate_host=true"
)

engine = create_engine(connection_string)

# Load table into dataframe
df = pd.read_sql("SELECT * FROM PatientStay", engine)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File c:\Users\markw\repos\Python-Course\.venv\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\markw\repos\Python-Course\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)   3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# File c:\Users\markw\repos\Python-Course\.venv\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
# ...
