# %% [markdown]
# # Functions Exercise

# %% [markdown]
# Write a function, named ```calculate_rectangle_area```, to return the area of a rectangle given its length and width.  Don't forget to add the docstring.

# %%
# Define the function ```calculate_rectangle_area``` here

# %%
length = 5
width = 4
# Invoke and test the function ```calculate_rectangle_area``` here

# %% [markdown]
# Write a function, named ```calculate_rectangle_details```, to return both the area and the perimeter  given its length and width. Return these as a tuple in the format (area, perimeter).

# %%
# Define the function ```calculate_rectangle_details``` here

# %%
length = 5
width = 4
# Invoke and test the function ```calculate_rectangle_details``` here
