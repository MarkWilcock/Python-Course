# %% [markdown]
# # Exercise: Basics

# %% [markdown]
# 1. Print "hello". (This is done for you already, but you can change the string if you want.)
# 2. Add another print statement to print three strings: "hello", "welcome", "good morning".
# 3. Add another print statement to have a comma separating the three strings.
# 4. Add another print statement to have 'STOP' at the end.

# %%
# Write your code here
print('hello')

# %% [markdown]
# Use Python as a calculator. Try addition, subtraction, multiplication, division, raising a number to a power (**)

# %%
# Write your code here
6+ 7 # example

# %% [markdown]
# Change `miles_journey` to 350 and recompute the values above.
# Add  a new line to calculate a new variable yards_journey using 1760 yards per mile and display it.

# %%
miles_journey = 200
km_journey = miles_journey * 1.60934 # there are about 1.61 km in a mile
furlongs_journey = miles_journey * 8 # there are 8 furlongs in a mile
km_journey, furlongs_journey # show both results

# %% [markdown]
# Optional Advanced Question: what does the following code cell do? Why are the results from the for loop in the first and second block different

# %%
print("Starting first block")

for i in range(4):
    print('i is:', i)
    
    print('double i is ', i * 2)

print("Ending first block")

print("Starting second block")
for i in range(4):
    print('i is:', i)

print('double i is ', i * 2)

print("Ending second block")
