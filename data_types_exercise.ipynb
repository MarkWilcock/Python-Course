# %% [markdown]
# # Exercise: DataTypes

# %% [markdown]
# Create variables for a person with
# * _name_ "Agatha"
# * _weight_ 75 (kg)
# * _height_ 1.75 (metres)
# * _is\_student_, a flag to define whether she is a student or not.
#
# Look at these in the variables inspector

# %%
name = 'Agatha'
name

# %%
# Create the weight variable here

# %%
# Create the height variable here

# %%
# Create the is_student variable here. Assume that Agatha is not a student.

# %% [markdown]
# Using the variables above, create some new variables by doing the following
# - add " Christie" to the name (this is done for you)
# - add 0.1m to the height
# - add 5 to the weight
# - enrol as a student

# %%
# Add your code here
new_name = name + " Christie"
new_name
