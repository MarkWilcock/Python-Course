# %% [markdown]
# # Useful Modules
#
# This lesson showcases typical useful commonly-used modules

# %% [markdown]
# The cowsay module allows an animal of your choice to say something

# %%
import cowsay
cowsay.cow('Hello, world!')
#cowsay.pig('Hello, world!')
#cowsay.turkey('Hello, world!')

# %% [markdown]
# ## The datetime module

# %%
import datetime

# %%
time_now = datetime.datetime.now()
time_now

# %%
may_15_2021 = datetime.datetime(2021, 5, 21)
may_15_2021

# %% [markdown]
# The strftime() method takeas a format string to return the datetime as a string

# %%
may_15_2021.strftime("%d %B %Y")

# %% [markdown]
# The timedelta() function returns a duration, the difference between two dates or times.

# %%
same_date_next_year = may_15_2021 + datetime.timedelta(days=365)
same_date_next_year.strftime("%d %B %Y")

# %%
from datetime import datetime

def days_between_dates(start_date, end_date):
    start_date = datetime.strptime(start_date, "%Y-%m-%d")
    end_date = datetime.strptime(end_date, "%Y-%m-%d")
    return (end_date - start_date).days

# %%
days_between_dates(start_date="2020-01-01", end_date="2023-01-02")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 days_between_dates(start_date="2020-01-01", end_date="2023-01-02")
#
# NameError: name 'days_between_dates' is not defined

# %% [markdown]
# ## The os module
#
# Provides operating system functions for handliling files, directories etc.

# %%
import os

# %%
os.environ
os.listdir()
os.get_exec_path()

# %% [markdown]
# ## The sys module
#
# Provide information about the current Python environment.

# %%
import sys

# %%
sys.version, sys.executable, sys.path

# %% [markdown]
# ## The math module
# Provides mathematical functions

# %%
import math

# %% [markdown]
# Given the area of a circle, what is its radius.

# %%
circle_area = 100
circle_radius = math.sqrt(circle_area / math.pi)
circle_radius
