# %% [markdown]
# # Answer: Control flow

# %% [markdown]
# ## Conditional statements with if - elif - else
#
# Given a temperature reading, return "cool" if under 15, "warm" if 15 or over but under 25 and "hot" if 25 or over.

# %%
temperature = int(input("Enter the temperature. Choose a whole number between 0 and 30."))

if temperature < 15:
    print("cool")
elif temperature < 25:
    print("warm")
else:
    print("hot")

# %% [markdown]
# ## Loop with for

# %%
for i in range(1, 11):
    print(i * i)

# %% [markdown]
# ## Loop with while
#
# Print the result of 15 raised to the power of 1,2,3... while the result is under 1,000,000.

# %%
result = 15
threshold = 1000000
while result < threshold:
    print(result)
    result = result * result

# %% [markdown]
# # Conditional flow
# This section covers if - elif - else and for.

# %% [markdown]
# Once the code cell below is run, the current_hour variable will be set to the hour of the current time. (int datatype)

# %%
from datetime import datetime

current_hour = datetime.now().hour
current_hour

# %% [markdown]
# If current_hour is less then 12, print good morning.  If less than 17, print good afternoon.  Otherwise, print good evening.

# %%
# Write your code here
if current_hour < 12:
    message = 'Good morning'
elif current_hour < 17: 
    message = 'Good afternoon'
else:
    message = 'Good evening'

message

# %% [markdown]
# Print the years between 2020 and 2030 inclusive.  Print each year on a new line.  The result should look like:
# 2020
# 2021
# ...
# 2030

# %%
# Write your code here
for i in range(2020, 2031, 1):
    print(i)

# %% [markdown]
# Print the leap years between 2020 and 2030 inclusive.  Print each year on a new line.

# %%
# Write your code here
for i in range(2020, 2031, 4):
    print(i)

def is_leap_year(year):
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0 ):
        return True
    else:
        return False
    
for i in range(2020, 2031, 1):
    if is_leap_year(i):
        print(i)
