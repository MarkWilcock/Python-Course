# %% [markdown]
# # Answer: Control flow

# %% [markdown]
# ## Conditional statements with if - elif - else
#
# Given a temperature reading, return "cool" if under 15, "warm" if 15 or over but under 25 and "hot" if over 25.

# %%
temperature = int(input("Enter the temprature. Choose a whole number between 0 and 30."))

if temperature < 15:
    print("cool")
elif temperature < 25:
    print("warm")
else:
    print("hot")

# %% [markdown]
# ## Loop with for

# %%
for i in range(1, 11):
    print(i * i)

# %% [markdown]
# ## Loop with while
#
# Print the result of 15 raised to the power of 1,2,3... while the result is under 1,000,000.

# %%
result = 15
threshold = 1000000
while result < threshold:
    print(result)
    result = result * result
