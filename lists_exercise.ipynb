# %% [markdown]
# # Lists Exercise
# In this exercise we create a list and perform various operations on it. Create a list with at least three items. The items should all be strings.  Choose fruit or flowers or cars or whatever.

# %%
# Write your code below.

# %% [markdown]
# Find the first item and second items in the list and print them out.

# %%
# Write your code below.

# %% [markdown]
# Find the last item.

# %%
# Write your code below.

# %% [markdown]
# Find out how many items are in the list.

# %%
# Write your code below.

# %% [markdown]
# Append another item to the list.

# %%
# Write your code below.

# %% [markdown]
# Insert an item into the third position.

# %%
# Write your code below.

# %% [markdown]
# Sort the list.

# %%
# Write your code below.
