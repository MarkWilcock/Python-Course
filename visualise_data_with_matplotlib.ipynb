# %% [markdown]
# # Visualise Data with matplotlib
#
# matplotlib is the long standing and most popular visualisation module.
# Other visualisation packages are available (seaborn, bokeh) and may be a better choice.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
survey = pd.read_csv(
    "Datasets/Covid Infection Survey 2021-02-12.csv",
    parse_dates=["Date"]
)
survey.head(2)
# Out:
#         Date  North East-Central  North East-Lower  North East-Upper  \
# 0 2021-01-02              0.0230            0.0192            0.0270
# 1 2021-01-03              0.0239            0.0200            0.0281
#
#    North West-Central  North West-Lower  North West-Upper  \
# 0              0.0209            0.0187            0.0231
# 1              0.0207            0.0185            0.0230
#
#    Yorkshire and The Humber-Central  Yorkshire and The Humber-Lower  \
# 0                            0.0136                          0.0115
# 1                            0.0134                          0.0114
#
#    Yorkshire and The Humber-Upper  ...  East of England-Upper  London-Central  \
# 0                          0.0158  ...                 0.0236          0.0333
# 1                          0.0157  ...                 0.0228          0.0326
#
#    London-Lower  London-Upper  South East-Central  South East-Lower  \
# 0        0.0309        0.0356              0.0205            0.0185
# 1        0.0302        0.0350              0.0202            0.0181
#
#    South East-Upper  South West-Central  South West-Lower  South West-Upper
# 0            0.0227              0.0094            0.0078            0.0111
# 1            0.0224              0.0098            0.0082            0.0117
#
# [2 rows x 28 columns]

# %%
# Create a line chart to show the change in the infection rate in London overtime
fig, ax = plt.subplots()
ax.plot(survey["Date"], survey["London-Central"], marker="o", color="blue")
ax.plot(survey["Date"], survey["London-Upper"], marker="v", color="grey")
ax.plot(survey["Date"], survey["London-Lower"], marker="v", color="grey")
ax.set_xlabel("Date")
ax.set_ylabel("Infection Rate")
ax.set_title(
    "Estimated infection rate in London with 95% credible intervals over a recent period"
)
fig.set_size_inches(4, 3)
plt.show()
